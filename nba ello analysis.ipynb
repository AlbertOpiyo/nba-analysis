# %%
import pandas as pd

# %%
# let us now load the data
download_url = 'https://raw.githubusercontent.com/fivethirtyeight/data/master/nba-elo/nbaallelo.csv'

# %%
import requests

# %%
response = requests.get(download_url)

# %%
print(response.status_code)
# Out:
# 200

# %%
with open('nba_all_elo.csv', 'wb') as f:
    f.write(response.content)

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 02E6-146A
#
#  Directory of C:\Users\Dell E5470
#
# 05/10/2023  02:50 PM    <DIR>          .
# 05/10/2023  02:50 PM    <DIR>          ..
# 05/02/2023  02:10 PM            31,696 # STRING METHODS.ipynb
# 04/17/2023  08:15 AM    <DIR>          .azuredatastudio
# 03/31/2023  08:30 PM                54 .bash_history
# 04/25/2023  11:13 AM    <DIR>          .conda
# 03/02/2023  06:34 AM                25 .condarc
# 03/02/2023  06:34 AM    <DIR>          .continuum
# 02/14/2023  03:27 PM    <DIR>          .idlerc
# 05/10/2023  02:47 PM    <DIR>          .ipynb_checkpoints
# 03/02/2023  06:46 AM    <DIR>          .ipython
# 03/02/2023  06:35 AM    <DIR>          .jupyter
# 04/17/2023  11:30 AM    <DIR>          .matplotlib
# 07/02/2022  11:17 AM    <DIR>          .ms-ad
# 08/05/2022  03:32 PM    <DIR>          .vscode
# 12/09/2021  10:03 PM    <DIR>          3D Objects
# 02/28/2023  06:50 PM    <DIR>          anaconda3
# ...

# %%
nba= pd.read_csv('nba_all_elo.csv')

# %%
type(nba)
# Out:
# pandas.core.frame.DataFrame

# %%
nba.shape
# Out:
# (126314, 23)

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
pd.set_option('display.max.columns', None) # allow all the columns to be displayed
pd.set_option('display.precision', 2) # fix the number of decimal places in each column

# %%
nba.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 126309         100            1     CLE  Cavaliers   82  1723.41  1704.39
# 126310         102            1     GSW   Warriors  104  1809.98  1813.63
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
nba.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# std       112.14     112.46      10.63      14.81     112.14     112.46
# ...

# %%
# no of games played by each team.
nba['team_id'].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# INJ      60
# PIT      60
# DTF      60
# TRH      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
nba['fran_id'].value_counts()
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# ...

# %%
# lets check how the lakers played.

nba['fran_id'] == 'Lakers'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 126309    False
# 126310    False
# 126311    False
# 126312    False
# 126313    False
# Name: fran_id, Length: 126314, dtype: bool

# %%
nba.loc[nba['fran_id'] == 'Lakers']
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 1136          569  194811040BLB   NBA        1     1949   11/4/1948
# 1152          577  194811060WSC   NBA        1     1949   11/6/1948
# 1159          580  194811090BOS   NBA        1     1949   11/9/1948
# 1170          586  194811110NYK   NBA        1     1949  11/11/1948
# 1183          592  194811130PRO   NBA        1     1949  11/13/1948
# ...           ...           ...   ...      ...      ...         ...
# 126016      63009  201504080DEN   NBA        1     2015    4/8/2015
# 126052      63027  201504100LAL   NBA        0     2015   4/10/2015
# 126086      63044  201504120LAL   NBA        0     2015   4/12/2015
# 126115      63058  201504130SAC   NBA        1     2015   4/13/2015
# 126137      63069  201504150LAL   NBA        0     2015   4/15/2015
#
#         seasongame  is_playoffs team_id fran_id  pts    elo_i    elo_n  \
# 1136             1            0     MNL  Lakers   84  1527.00  1542.25
# ...

# %%
nba.loc[nba['fran_id'] == 'Lakers', 'team_id']
# Out:
# 1136      MNL
# 1152      MNL
# 1159      MNL
# 1170      MNL
# 1183      MNL
#          ...
# 126016    LAL
# 126052    LAL
# 126086    LAL
# 126115    LAL
# 126137    LAL
# Name: team_id, Length: 6024, dtype: object

# %%
nba.loc[nba['fran_id'] == 'Lakers', 'team_id'].value_counts() # there are two categories of lakers i.e LAL  and MNL
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
nba.loc[nba['team_id'] == 'MNL', 'date_game'] # lets determine when the MNl Lakers played
# Out:
# 1136     11/4/1948
# 1152     11/6/1948
# 1159     11/9/1948
# 1170    11/11/1948
# 1183    11/13/1948
#            ...
# 9701     3/19/1960
# 9702     3/20/1960
# 9709     3/22/1960
# 9711     3/24/1960
# 9715     3/26/1960
# Name: date_game, Length: 946, dtype: object

# %%
# lets see when MNL played earliest.
nba.loc[nba['team_id'] == 'MNL', 'date_game'].max() # the date is misleading since it is a string. it should be converted to datetime.
# Out:
# '4/9/1959'

# %%
nba['date_played'] = pd.to_datetime(nba['date_game'])

# %%
nba.loc[nba['team_id'] == 'MNL', 'date_played'].max() # this is when the MNL first played basketball.
# Out:
# Timestamp('1960-03-26 00:00:00')

# %%
# let us determine the total points by the BOS team.
total_bos_points = nba.loc[nba['team_id'] == 'BOS', 'pts'].sum()
total_bos_points
# Out:
# 626484

# %%
# let us calculate the avaerage points per year of BOS team.
years_bos_played = len(nba.loc[nba['team_id'] == 'BOS', 'date_played'].apply(lambda v: v.year).unique())
total_bos_points / years_bos_played
# Out:
# 8949.771428571428

# %%
'pts' in nba.axes[1]
# Out:
# True

# %%
nba.iloc[-2] # this finds the second to last row
# Out:
# gameorder                      63157
# game_id                 201506170CLE
# lg_id                            NBA
# _iscopy                            0
# year_id                         2015
# date_game                  6/16/2015
# seasongame                       102
# is_playoffs                        1
# team_id                          CLE
# fran_id                    Cavaliers
# pts                               97
# elo_i                        1700.74
# elo_n                        1692.09
# win_equiv                      59.29
# opp_id                           GSW
# opp_fran                    Warriors
# opp_pts                          105
# opp_elo_i                    1813.63
# opp_elo_n                    1822.29
# game_location                      H
# game_result                        L
# forecast                        0.48
# notes                            NaN
# date_played      2015-06-16 00:00:00
# Name: 126312, dtype: object

# %%
# lets output a new DataFrame with the rows from 5555 to 5559 (inclusive) and the columns 'fran_id', 'opp_fran', 'pts', and 'opp_pts'

nba.loc[5555:5559, ['fran_id', 'opp_fran', 'pts', 'opp_pts']]
# Out:
#       fran_id  opp_fran  pts  opp_pts
# 5555  Pistons  Warriors   83       56
# 5556  Celtics    Knicks   95       74
# 5557   Knicks   Celtics   74       95
# 5558    Kings    Sixers   81       86
# 5559   Sixers     Kings   86       81

# %%
# let us find the statistics of the current decade.

current_decade = nba[nba['year_id'] > 2010]
current_decade
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 113656           1            0     MIA       Heat   80  1547.36  1543.16
# ...

# %%
# lets us clean the data by looking at the nulls.
nba['notes'].notnull()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 126309    False
# 126310    False
# 126311    False
# 126312    False
# 126313    False
# Name: notes, Length: 126314, dtype: bool

# %%
games_with_notes = nba[nba['notes'].notnull()] # there are 5424 rows that are not null.
games_with_notes
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 930           466  194801300BLB   NBA        1     1948   1/30/1948
# 931           466  194801300BLB   NBA        0     1948   1/30/1948
# 1084          543  194803230CHS   NBA        1     1948   3/23/1948
# 1085          543  194803230CHS   NBA        0     1948   3/23/1948
# 1088          545  194803250CHS   NBA        1     1948   3/25/1948
# ...           ...           ...   ...      ...      ...         ...
# 122207      61104  201401160ATL   NBA        0     2014   1/16/2014
# 123916      61959  201411120MIN   NBA        1     2015  11/12/2014
# 123917      61959  201411120MIN   NBA        0     2015  11/12/2014
# 124862      62432  201501150MIL   NBA        0     2015   1/15/2015
# 124863      62432  201501150MIL   NBA        1     2015   1/15/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts    elo_i    elo_n  \
# ...

# %%
ers_teams = nba[nba['fran_id'].str.endswith('ers')]
ers_teams
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 9               5  194611020STB   NBA        0     1947  11/2/1946
# 16              9  194611050DTF   NBA        1     1947  11/5/1946
# 20             11  194611070PRO   NBA        0     1947  11/7/1946
# 22             12  194611070STB   NBA        0     1947  11/7/1946
# ...           ...           ...   ...      ...      ...        ...
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts    elo_i    elo_n  \
# 7                1            0     PRO  Steamrollers   59  1300.00  1305.15
# ...

# %%
#lets analyze  containing only the rows where the team_id is 'BLB', the points scored by the team (pts) is greater than 100, and the points scored by the opposing team (opp_pts) is also greater than 100.

nba[(nba['team_id'] == 'BLB') & (nba['pts'] > 100) & (nba['opp_pts'] > 100)]
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 1726        864  194902260BLB   NBA        0     1949  2/26/1949          53
# 4890       2446  195301100BLB   NBA        0     1953  1/10/1953          32
# 4909       2455  195301140BLB   NBA        0     1953  1/14/1953          34
# 5208       2605  195303110BLB   NBA        0     1953  3/11/1953          66
# 5825       2913  195402220BLB   NBA        0     1954  2/22/1954          60
#
#       is_playoffs team_id    fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 1726            0     BLB  Baltimore  114  1421.94  1419.43      38.56    MNL
# 4890            0     BLB  Baltimore  126  1328.67  1356.65      25.80    BOS
# 4909            0     BLB  Baltimore  104  1349.83  1346.36      24.88    MNL
# 5208            0     BLB  Baltimore  107  1284.52  1282.24      19.58    NYK
# 5825            0     BLB  Baltimore  110  1303.75  1301.97      20.74    BOS
#
# ...

# %%
# let us find the total points. 
nba['pts'].sum()
# Out:
# 12976235

# %%
# let us find the unique fran id
nba['fran_id'].unique()
# Out:
# array(['Huskies', 'Knicks', 'Stags', 'Falcons', 'Capitols', 'Celtics',
#        'Steamrollers', 'Ironmen', 'Bombers', 'Rebels', 'Warriors',
#        'Baltimore', 'Jets', 'Pistons', 'Lakers', 'Kings', 'Hawks',
#        'Denver', 'Olympians', 'Redskins', 'Waterloo', 'Packers', 'Sixers',
#        'Wizards', 'Bulls', 'Thunder', 'Squires', 'Stars', 'Rockets',
#        'Colonels', 'Pacers', 'Nuggets', 'Spurs', 'Spirits', 'Sounds',
#        'Floridians', 'Nets', 'Condors', 'Bucks', 'Suns', 'Clippers',
#        'Cavaliers', 'Trailblazers', 'Sails', 'Jazz', 'Mavericks',
#        'Pelicans', 'Heat', 'Timberwolves', 'Magic', 'Grizzlies',
#        'Raptors', 'Hornets'], dtype=object)

# %%
# let us group the fran by group fran_id
group_fran = nba.groupby('fran_id', sort=False)

# %%
# let see the points of each fran
group_fran['pts'].sum()
# Out:
# fran_id
# Huskies           3995
# Knicks          582497
# Stags            20398
# Falcons           3797
# Capitols         22387
# Celtics         626484
# Steamrollers     12372
# Ironmen           3674
# Bombers          17793
# Rebels            4474
# Warriors        591224
# Baltimore        37219
# Jets              4482
# Pistons         572758
# Lakers          637444
# Kings           569245
# Hawks           567261
# Denver            4818
# Olympians        22864
# Redskins          5372
# Waterloo          4921
# Packers           6193
# Sixers          585891
# Wizards         474809
# Bulls           437269
# Thunder         437735
# Squires          91127
# Stars            84940
# Rockets         432504
# Colonels         94435
# Pacers          438288
# Nuggets         445780
# Spurs           453822
# Spirits          85874
# Sounds           75582
# Floridians       49568
# Nets            417809
# Condors          49642
# Bucks           418326
# ...

# %%
# let us calculate the year results
year_results = nba[nba['fran_id'] == 'Bulls'].groupby(['year_id', 'game_result'])

# %%
year_results['game_id'].count()
# Out:
# year_id  game_result
# 1967     L              51
#          W              33
# 1968     L              57
#          W              30
# 1969     L              49
#                         ..
# 2013     W              50
# 2014     L              38
#          W              49
# 2015     L              38
#          W              56
# Name: game_id, Length: 98, dtype: int64

# %%
nba[
    (nba['fran_id'] == 'Warriors') &
    (nba['year_id'] == 2015)
].groupby(['is_playoffs', 'game_result'])['game_id'].count()
# Out:
# is_playoffs  game_result
# 0            L              15
#              W              67
# 1            L               5
#              W              16
# Name: game_id, dtype: int64

# %%
nba_copy = nba.copy() # makes a cpy of the current dataset

# %%
nba_copy.loc[0, 'team_id'] = 'MIA'

# %%
print(nba.loc[0]) # Print the first row of the original DataFrame
# Out:
# gameorder                          1
# game_id                 194611010TRH
# lg_id                            NBA
# _iscopy                            0
# year_id                         1947
# date_game                  11/1/1946
# seasongame                         1
# is_playoffs                        0
# team_id                          TRH
# fran_id                      Huskies
# pts                               66
# elo_i                         1300.0
# elo_n                        1293.28
# win_equiv                      40.29
# opp_id                           NYK
# opp_fran                      Knicks
# opp_pts                           68
# opp_elo_i                     1300.0
# opp_elo_n                    1306.72
# game_location                      H
# game_result                        L
# forecast                        0.64
# notes                            NaN
# date_played      1946-11-01 00:00:00
# Name: 0, dtype: object

# %%
# Print the first row of the copied DataFrame
print(nba_copy.loc[0])
# Out:
# gameorder                          1
# game_id                 194611010TRH
# lg_id                            NBA
# _iscopy                            0
# year_id                         1947
# date_game                  11/1/1946
# seasongame                         1
# is_playoffs                        0
# team_id                          MIA
# fran_id                      Huskies
# pts                               66
# elo_i                         1300.0
# elo_n                        1293.28
# win_equiv                      40.29
# opp_id                           NYK
# opp_fran                      Knicks
# opp_pts                           68
# opp_elo_i                     1300.0
# opp_elo_n                    1306.72
# game_location                      H
# game_result                        L
# forecast                        0.64
# notes                            NaN
# date_played      1946-11-01 00:00:00
# Name: 0, dtype: object

# %%
nba_copy.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     MIA  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
# lets find the difference in points. 
nba_copy['difference'] = nba_copy['pts'] - nba_copy['opp_pts']

# %%
nba_copy['difference'].max()
# Out:
# 68

# %%
## let us rename some colmuns.
nba_copy.rename(
    columns={
        'game_result': 'result',
        'game_location': 'location'
    },
    inplace=True
)

# %%
# let us drop some columns.
elo_columns = ['elo_i', 'elo_n', 'opp_elo_i', 'opp_elo_n']
nba_copy.drop(elo_columns, axis=1)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     MIA    Huskies   66      40.29    NYK
# ...

# %%
# the date_game is a string. let us convert it to date time for easier analysis.

nba['date_game'] = pd.to_datetime(nba['date_game'])
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  datetime64[ns]
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
# hw many game locations are there?- 3 unique game location.
nba['game_location'].unique()
# Out:
# array(['H', 'A', 'N'], dtype=object)

# %%
# since there are three categories of the game locations lets convert it into categorical datatype.
nba['game_location'] = pd.Categorical(nba['game_location'])
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  datetime64[ns]
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
# lets do the same to game results
nba['game_result'] = pd.Categorical(nba['game_result'])

# %%
clean_nba = nba.dropna(axis=1)
clean_nba.shape
# Out:
# (126314, 23)

# %%
# let us fill the null values in nba data frame
nba_copy['notes'].fillna(
    value='no notes at all',
    inplace=True
)
nba_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 25 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   gameorder    126314 non-null  int64
#  1   game_id      126314 non-null  object
#  2   lg_id        126314 non-null  object
#  3   _iscopy      126314 non-null  int64
#  4   year_id      126314 non-null  int64
#  5   date_game    126314 non-null  object
#  6   seasongame   126314 non-null  int64
#  7   is_playoffs  126314 non-null  int64
#  8   team_id      126314 non-null  object
#  9   fran_id      126314 non-null  object
#  10  pts          126314 non-null  int64
#  11  elo_i        126314 non-null  float64
#  12  elo_n        126314 non-null  float64
#  13  win_equiv    126314 non-null  float64
#  14  opp_id       126314 non-null  object
#  15  opp_fran     126314 non-null  object
#  16  opp_pts      126314 non-null  int64
#  17  opp_elo_i    126314 non-null  float64
# ...

# %%
import random

# Create a list of numbers
numbers = [1, 2, 3, 4, 5]

# Shuffle the list
random.shuffle(numbers)

# Print the shuffled list
print(numbers)
# Out:
# [1, 5, 2, 4, 3]

# %%
# reviews.iloc[:, 0]- retrieviing a column in a dataframe
